# %%
import configparser
import tweepy

# read config
config = configparser.ConfigParser()
config.read('config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# authenticate
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#public_tweets = api.home_timeline()
# for tweets in api.search_tweets(q="#amazon", lang="en"):
#     print(tweet.text)
public_tweets = api.search_tweets(q="amazon", lang="en")

for tweets in public_tweets:
    print(tweets)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001ACA969F310>, _json={'created_at': 'Fri Feb 10 05:45:50 +0000 2023', 'id': 1623921162957856769, 'id_str': '1623921162957856769', 'text': 'Type: BUY\nAmount: 300\nCurrency: CAD 🇨🇦\nPayment method: Amazon CA GiftCard \nPremium: 7.0%\nPrice: 31,442\nLINK:… https://t.co/pGoxvmgn2q', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pGoxvmgn2q', 'expanded_url': 'https://twitter.com/i/web/status/1623921162957856769', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://robosats.com" rel="nofollow">Robosats OrderBook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1505638398198964224, 'id_str': '1505638398198964224', 'name': 'Robosats OrderB
# ...

# %%
import pandas as pd

# create dataframe
columns = ['id', 'user', 'Tweet']

data = []
for tweet in public_tweets:
    data.append([tweet.id, tweet.user.name, tweet.text])

df = pd.DataFrame(data, columns=columns)

df.to_csv('tweets.csv')

# %%
df
# Out:
#                      id                                               user  \
# 0   1623921162957856769                                 Robosats OrderBook
# 1   1623921160302854146                                 Robosats OrderBook
# 2   1623921157706510336                                 Robosats OrderBook
# 3   1623921143785857024                                      L. B-Smith ☮️
# 4   1623921138941431813                                             Hannah
# 5   1623921138371006467    Jesse Seth Frankel--YA Fantasy/Adventure Author
# 6   1623921129621684226  hapeewecarts friend mssg me if u have any conc...
# 7   1623921128724135936                               Stefan aka DJ Speedy
# 8   1623921125725196295                                               kubo
# 9   1623921123820974080                                                 ゆか
# 10  1623921114945822720                                      Val Man LECKA
# ...

# %%
tx = ['Amazon', 'Google', 'Good','Account','Prize']
df1 = pd.DataFrame(tx, columns=['Text'])
df1
# Out:
#       Text
# 0   Amazon
# 1   Google
# 2     Good
# 3  Account
# 4    Prize

# %%
df['flag'] = df['Tweet'].apply(lambda x: 1 if any(i in x for i in tx) else 0)
df
# Out:
#                      id                                               user  \
# 0   1623921162957856769                                 Robosats OrderBook
# 1   1623921160302854146                                 Robosats OrderBook
# 2   1623921157706510336                                 Robosats OrderBook
# 3   1623921143785857024                                      L. B-Smith ☮️
# 4   1623921138941431813                                             Hannah
# 5   1623921138371006467    Jesse Seth Frankel--YA Fantasy/Adventure Author
# 6   1623921129621684226  hapeewecarts friend mssg me if u have any conc...
# 7   1623921128724135936                               Stefan aka DJ Speedy
# 8   1623921125725196295                                               kubo
# 9   1623921123820974080                                                 ゆか
# 10  1623921114945822720                                      Val Man LECKA
# ...
